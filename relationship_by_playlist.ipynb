# %%
import json
import requests
import spotipy
import spotipy.util as util
import pandas as pd
from pandas import DataFrame
import numpy as np
import random
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
#username可以隨意打
username = '史罷特喎'
scope = 'user-library-read'

token = util.prompt_for_user_token(username, scope,
                          client_id = '使用自己的',
                          client_secret = '使用自己的',
                          # 要在web app 加入 redirect 的白名單
                          redirect_uri = 'http://localhost/')


#client_id = 'c042d148a3b047c69634bddadbee8ab0'
#client_secret = '4ba043d1f92c4fa0bda86da381681e8a'
                         
# 複製   http://localhost/  後面的東西
#等等出現的對話框 要輸入上面複製的東西
# Out:
#             User authentication requires interaction with your
#             web browser. Once you enter your credentials and
#             give authorization, you will be redirected to
#             a url.  Paste that url you were directed to to
#             complete the authorization.
#
#
# Opened https://accounts.spotify.com/authorize?client_id=c042d148a3b047c69634bddadbee8ab0&response_type=code&redirect_uri=http%3A%2F%2Flocalhost%2F&scope=user-library-read in your browser
#
#
# Enter the URL you were redirected to: ?code=AQDPX3Ls2P83zkrjJKh50wY29yeQzbM7hgpihDS0tzHgFzcj48vzDYyhEBf_4VbinXR7ZNCS8UHIMnp_sp7_F44xsCJKpT_v1JQgJbzdFxh96CUcVerOXH_NWMEwvHS0Vw0sGpjYDNJ6Vtv-no2JuIiaQXR97GA2KInj7fCCb7LAMxV9n3wunZHmPD5s8AoDDo2zTcU3sR_7Tw

# %%
headers = {"Authorization": "Bearer {}".format(token)}

# %%
# https://api.spotify.com/v1/users/你的歌單名字(ex: 中文嘻哈)/playlists/上面歌單/tracks?offset=0&limit=50",headers=headers

#重複抓取所需的資料 get_spotify_data
def get_spotify_data(playlist_uri):
    
    assign_word = "user"
    
    if assign_word in playlist_uri:          #取出網址所需要的部分
        playlist_uri = playlist_uri.split("/")
        get_slash = playlist_uri[6]
        uri_gogo =  "https://api.spotify.com/v1/users/mymusic/playlists/" + get_slash + "tracks?offset=0&limit=50"
    
    else:
        playlist_uri = playlist_uri.split("/")
        get_slash = playlist_uri[4]
        uri_gogo =  "https://api.spotify.com/v1/users/mymusic/playlists/" + get_slash + "tracks?offset=0&limit=50"
    
    
    
    #從API抓資料：
    
    hi = requests.get(uri_gogo,headers = headers)

    
    
    #資料從json轉成串列(每首歌的特徵值為一個字典)(也就是20個字典在一個播放清單的串列裡)：
    data = json.loads(hi.text)         
    someone_songs_attributes = [ ]     # song's attribute
    someone_songs_names = [ ]          #song'name 

    
    def get_song_attributes(response_text):
        return json.loads(response_text)
    
    #拿到歌曲的uri
    for item in data.get('tracks')['items']:
        
        song_ids = item['track']['uri'].split(':')[2]
        song_name = item['track']['name']
        song_attributes = requests.get(f"https://api.spotify.com/v1/audio-features/{song_ids}", headers = headers)
        someone_songs_attributes.append(get_song_attributes(song_attributes.text))
        someone_songs_names.append(song_name)
    
    
    
    #把不需要的變數丟掉(變數第一篩)：    
    for i in someone_songs_attributes:
        i.pop('type')
        i.pop('id')
        i.pop('uri')
        i.pop('track_href')
        i.pop('analysis_url')
        i.pop('time_signature')

    
    
    #將得到的資料整理成表格(取var)：
    df = pd.DataFrame(someone_songs_attributes)
    col_name = df.columns.tolist()
    col_name = sorted(col_name)
    col_name.insert(0, "song")
    df = df.reindex(columns = col_name)
    df["song"] = someone_songs_names
    
    
    
    #把平均或取變異數過後的變數和變數名稱整理成串列：
    column = 0
    variable_title = [ ]
    variable_value = [ ]
    temp = [ ]
    
    for i in col_name:

        if column >= 1:
            
            average_song = df[i].std()
            variable_title.append(i)
            variable_value.append(average_song)
            
        column += 1
    
    
    
    #把要的變數用變數名稱判斷來抓出他的值，加到temp裡面，最後return出這個歌單的變數(變數第二篩)：
    
    for i , j in zip(variable_title,variable_value):
        
        i = str(i)
        j = float(j)
        
        if i == 'speechiness' or i == 'valence':
            temp.append(j)
    
    
    return temp

# %%
# path設置你放excel檔的路徑
#/Users/boyen/Desktop/ccClub/spotify專案/資料測試集.xlsx

path = '/Users/boyen/Desktop/ccClub/spotify專案/'
fname = path +'資料測試集.xlsx'

df_test = pd.read_excel(fname, 0)
df_test
#df_test["連結一"]
# Out:
#                                                   連結一  \
# 0   https://open.spotify.com/playlist/2uOx3uPcRy05...
# 1   https://open.spotify.com/playlist/7jUXg4DTIc1a...
# 2   https://open.spotify.com/playlist/0lqJgvDkZk3G...
# 3   https://open.spotify.com/playlist/2Cvgv79npINQ...
# 4   https://open.spotify.com/playlist/4OuBNLWJucVf...
# ..                                                ...
# 94  https://open.spotify.com/playlist/4hMHSNALj4yF...
# 95  https://open.spotify.com/playlist/1HZJcEispDQm...
# 96  https://open.spotify.com/playlist/5uj7VBiyRrtR...
# 97  https://open.spotify.com/playlist/3S3CQuepi4z9...
# 98  https://open.spotify.com/user/21mw7w6rcbfrryca...
#
#                                                   連結二  朋友關係
# 0   https://open.spotify.com/playlist/5CGCfZ7KHZIa...     1
# 1   https://open.spotify.com/playlist/1xFk1UVomG1R...     1
# 2   https://open.spotify.com/playlist/6WLvPX3eApl3...     1
# 3   https://open.spotify.com/playlist/2nlpcmlX0aRj...     1
# 4   https://open.spotify.com/playlist/40QutHmypjg4...     1
# ..                                                ...   ...
# 94  https://open.spotify.com/playlist/4CgVfYzMtriE...     0
# 95  https://open.spotify.com/playlist/3u0FU6ZCFquA...     0
# 96  https://open.spotify.com/playlist/1xRULc1Pl6id...     0
# 97  https://open.spotify.com/playlist/3HbFyu4KGH8I...     0
# 98  https://open.spotify.com/playlist/72xETCQ0zjX3...     0
#
# [99 rows x 3 columns]

# %%
values = df_test.values
values = list(values)
#print(values)
print(type(values))
# Out:
# <class 'list'>

# %%
print(len(values))
# Out:
# 99

# %%
for i in values:
    print(i)
# Out:
# ['https://open.spotify.com/playlist/2uOx3uPcRy05y5c1TAILIp?si=sQnzOQNARWqDancFyKoO7A'
#  'https://open.spotify.com/playlist/5CGCfZ7KHZIaIRHTXf47CC?si=n_mrE1mvQ5Wzk7PCtNcf-Q'
#  1]
# ['https://open.spotify.com/playlist/7jUXg4DTIc1aeAO9tM5j0w?si=i4HlB5a1TCe3bEv2aVu3ig'
#  'https://open.spotify.com/playlist/1xFk1UVomG1RYcilwEAfmu?si=kuPjtJ4VRyKZwrnDikBQxw'
#  1]
# ['https://open.spotify.com/playlist/0lqJgvDkZk3GFxq7VouhWh?si=uehgZ2NfQt22mvRxGCE-kA'
#  'https://open.spotify.com/playlist/6WLvPX3eApl3NeDR1yJE4a?si=kk4HsmiFTDyTqft1jIfF6w'
#  1]
# ['https://open.spotify.com/playlist/2Cvgv79npINQDfRNVacoQg?si=dAtMU7E2QWmZ_aVbksM_aA'
#  'https://open.spotify.com/playlist/2nlpcmlX0aRjf8ddeJFaDc?si=7o-FnNwGR3KXy-e11hOL5w'
#  1]
# ['https://open.spotify.com/playlist/4OuBNLWJucVfU6dylW1qMy?si=lfDB54FXTz6-_ArVrTM32A'
#  'https://open.spotify.com/playlist/40QutHmypjg4vv7eNqaxqf?si=MFYRhxywQriXMY0bt6sl2A'
#  1]
# ['https://open.spotify.com/playlist/4CgVfYzMtriEMyMpP6RV95?si=8aiWdvzyR3iQdKwKDNg-gg'
#  'https://open.spotify.com/playlist/0MqicfXjtnyDQ2BO1aVERS?si=Wm3d8YLbRju_qcZ2z2UUtA'
#  1]
# ['https://open.spotify.com/playlist/50aUNv7HOID73lXM3LFODo?si=BXVqmLEGTLWsdVCyySrH8A'
#  'https://open.spotify.com/playlist/1xRULc1Pl6idSuMvLV5icV?si=GWemC-uLT7m1ou7LcVqH2Q'
#  1]
# ['https://open.spotify.com/playlist/0M7cTFPWNWczvzBZhGNElp?si=ZxtE1eDlS5q2Ta-Nz96a1A'
#  'https://open.spotify.com/playlist/3HbFyu4KGH8IDrJtRTP7S9?si=gSs6_tiSSESAHtvAYR30zA'
#  1]
# ['https://open.spotify.com/playlist/7zhIszcMHTpo8bK4HIk1NC?si=y5rzE34rQia3OiZSdSWRGQ'
#  'https://open.spotify.com/playlist/72xETCQ0zjX3Gt9qJZwgnN?si=MTv9JcRhRE-Lzwo8--oyhw'
#  1]
# ['https://open.spotify.com/playlist/7p2lPvgbihma0EGgH6HMdD?si=Dxj_PaLCTvme3a6XCeu_QQ'
#  'https://open.spotify.com/playlist/037Kw1v0yBgyxnB5c5JVBg?si=YYattVLHQfuZCn0CgZ_NNA'
#  1]
# ['https://open.spotify.com/playlist/0bGo6h4dBfi5a86AgSlrEJ?si=cLpu-eqtRJSPJociBTllhw'
#  'https://open.spotify.com/playlist/0JRlDXWexzLVdaeauPGjz2?si=GwTJGuYsSPeyBGcOmpkzUw'
#  1]
# ['https://open.spotify.com/playlist/5FIYbu78vnCSaYeOU7XIQX?si=sfR1AAxvTiKuF5YB0Bt4dw'
#  'https://open.spotify.com/playlist/6OD8kZoWc8ym5suXz4MCFq?si=sC1g73MfSXe0_qg2YBD4Vg'
#  1]
# ['https://open.spotify.com/playlist/1dnu7thFGjDG4XAdanvacO?si=puDxtKkeQMmRQWIObOci2g'
#  'https://open.spotify.com/playlist/3u0FU6ZCFquAEaORCtI88E?si=Rc0FffmzS36V3gKBYnsogA'
#  1]
# ['https://open.spotify.com/playlist/4fcUnlhy1tlIxavhUmtmSy?si=PSj6PtycT9yWneS9lwS0TA'
#  'https://open.spotify.com/playlist/6elTsuf1JPZQZitMeqwQez?si=uo3dPPIYTiq3Q0YSugSquw'
#  1]
# ['https://open.spotify.com/playlist/20VsjYLUi8yIulO6l0mxLR?si=zvpZMVYhSF-UprrEWFzbyg'
#  'https://open.spotify.com/playlist/2vNWRMdJWq5Cdh6GWHuink?si=TM52GZf4QLe0Scyb8RZcLw'
#  1]
# ['https://open.spotify.com/playlist/3k9gzqFrnIe3fxzeyVhRNx?si=B_PYqxn0TNWr59g-FTqbjg'
#  'https://open.spotify.com/playlist/5a2wrjiadZIzNoaznFhBEM?si=lHDFggNXTfm8KjXCStWBeQ'
#  1]
# ['https://open.spotify.com/playlist/3k7SbojaD1xDyEXZjaksn3?si=HQaSbMeqTO-LtJZQxQmaRg'
#  'https://open.spotify.com/playlist/2n02QGYSxisudxqAWMO9J1?si=tyuoEGHATkCHy6WVfzCTFA'
#  1]
# ['https://open.spotify.com/playlist/5m2sRlsUfLh17juvuomrZM?si=nlK4AVH8QkCEfZQEzAAMLw'
#  'https://open.spotify.com/playlist/6zwHji3HvBnlA0UMOiuq3B?si=h7ph4d0MRCCOgKM_22WFaw'
#  1]
# ['https://open.spotify.com/playlist/4B4lFX79W1WYgphMpEp2Ty?si=7QhasmgtT-m1VZ8sSRvd0w'
#  'https://open.spotify.com/playlist/6b3rzxp5ICQgHfVOjP2kSl?si=L1LPjYvKQs2chZ2ZTaOA4Q'
#  1]
# ['https://open.spotify.com/playlist/5XxlH4PffVqbf2KQQVgnVC?si=YS1eO_4OQjy8abob-zqnOg'
#  'https://open.spotify.com/playlist/6ikdVXy6NjXKczKQbswBlT?si=ksrfECBnRPyV1Zm4hQbjSw'
#  1]
# ['https://open.spotify.com/user/1vcmfo1btai20s1sn1mz5wa4a/playlist/1Te0ZQDWCGZGwQwWOdX9Ry?si=kRV4BAZ2Q2uUhGpvuFbclQ'
#  'https://open.spotify.com/playlist/5uj7VBiyRrtRFy3LTxgmlz?si=VgmhDASBTdie2Y4REnlTOA'
#  1]
# ['https://open.spotify.com/playlist/58i1xtQl1sHERuimiHLYjy?si=cyNoKseYRtWC-NumjmWgZA'
#  'https://open.spotify.com/playlist/3S3CQuepi4z9CjupXZf1MX?si=JQ9oWe1SS1OJqFZa8XlsJQ'
#  1]
# ['https://open.spotify.com/playlist/3zjXUdzBpxBUtSB7dcZB41?si=6IpxSUQsQTG9NF1UHEVWnA'
#  'https://open.spotify.com/user/21mw7w6rcbfrryca2hhlhazzi/playlist/0PiN0vClqosnTqqF0TAtCX?si=J7p0rZcwRJ23L-NTHfVCmA'
#  1]
# ['https://open.spotify.com/playlist/5c9EGBDYF72qOgBOYQhDhY?si=M8SGZ4L6RbSOrFQKRuMLKw'
#  'https://open.spotify.com/user/8dyqkk501hr5l18x3e65lhrif/playlist/5oSBMWAXqtHZaEdX6tfIy5?si=LpOeNH2bSHqTc3ZXuCLOMw'
#  1]
# ['https://open.spotify.com/playlist/4lzyljiq7qDljWPJWF3Vcd?si=vHhtrO-KQZm3gv3lrm_tcg'
#  'https://open.spotify.com/playlist/4hMHSNALj4yFMX6rRRzAKV?si=kwxyTCnOSf6tfZJlxK7bbA'
#  1]
#  1]
# ['https://open.spotify.com/playlist/6ApwRH9p3mVYTSk10A44G4?si=M5ZfYTqUTzucccSsMUpjYg '
#  'https://open.spotify.com/playlist/1qLBhBAjsEAkG2G1mXknnh?si=zzR3EcPyRvmmrOzVtrbZ9w'
#  1]
# ['https://open.spotify.com/playlist/6IW0N3SjiWJTp4cwqTUrQZ?si=DO6rJA4zTdCOF3XMs8XycA'
#  'https://open.spotify.com/playlist/6Y1Q4TXkLQbmj0gLlRih0H?si=AuhOyJCxTlW0HtxdJcBTrA '
#  1]
# ['https://open.spotify.com/playlist/1rIgHYILyO2YUENqTum1mV?si=HCphm5MKQpaUX_8itbBTbQ '
#  'https://open.spotify.com/playlist/1hIiZ029o0F0qXu9onqfer?si=H21N2E67SO2dCropOvRFSg '
#  1]
# ['https://open.spotify.com/playlist/11YpOEgJ3OtpW1TM3haWa8?si=Pp9Yl3o7SjW3YLiydxNMsA '
#  'https://open.spotify.com/playlist/7zbdEI9ZvwFzdGNlTQTDxF?si=rAAX5IWeRM-V-Uu2WjLi4g '
#  1]
# ['https://open.spotify.com/playlist/45iFd4TWTTtvl4WDuosCjS?si=lWvvPxTXQG2wCAEufOAxvQ '
#  'https://open.spotify.com/playlist/4CaVsnxC9IjZoncrLWRm5O?si=vbIKpsgrTgu3TWkRjYix0w '
#  1]
# ['https://open.spotify.com/playlist/1n1hbfajXbjs1ATjQ52ibG?si=1_m9u-QZQ5umyUhZc8toTw '
#  'https://open.spotify.com/playlist/5xpmhWfIOLCTdxPhEfeiJf?si=qjgTd3g-QTKPuRgKZze2jA '
#  1]
# ['https://open.spotify.com/playlist/2dDY7Hqbw85CAmGsmj1dkE?si=A_Vnrqw0Q5eQKN3HOeAbRw '
#  'https://open.spotify.com/playlist/55kfGg5lRXSIYQeYnRYoRd?si=Bv4xHy2FTH6k2v7AZ--Faw '
#  1]
# ['https://open.spotify.com/playlist/1eumV8I2mWpjLdRc80Sa6e?si=SEL6-ARhTK2aIGIc-XLW1g '
#  'https://open.spotify.com/playlist/1PYxmBiM5SQMrQGZuX63C5?si=HTjvoJ5vR0uey0ABOdpCKw '
#  1]
# ['https://open.spotify.com/playlist/4h8QzTTf4wFIwcWfqkY0ws?si=WgCpYV5PQzqCeV7mvqajRA '
#  'https://open.spotify.com/playlist/4nvHBR3fkwiaRDzoPif99v?si=xSKY4Nu1QXmxECUZkFtESg '
#  1]
# ['https://open.spotify.com/playlist/34lnwRFQajFSXZ21183oWV?si=EPENhetrQT2nAhzvCnvvWw '
#  'https://open.spotify.com/playlist/1gV7SPbVODvtpU0XHvnQ1k?si=gkZJlf5_S8ClIXdymWniaQ '
#  1]
# ['https://open.spotify.com/playlist/26m24atFhe7D6dDD3Z5ccn?si=CYoOEU68Qf2w3VtzFb3lpQ '
#  'https://open.spotify.com/playlist/3CcXcrUiamL8fUsqVPjjDR?si=dCOBm-OfTYeksumpe6e85w '
#  1]
# ['https://open.spotify.com/playlist/1G173MFB8uCBbu3XSQxxWO?si=_Ynb1fA_SzmrdqyBvfuXlg '
#  'https://open.spotify.com/playlist/0Z7PpUmvS0mJRL32nXtPdh?si=VQugWYu2RQyGeI5CA4aeNg '
#  1]
# ['https://open.spotify.com/playlist/1nOfe1pHO5X2lmntXzh00y?si=Bw4trJWlQt6sEqoC1BkSeQ '
#  'https://open.spotify.com/playlist/311FoNkX4L1SeSyGTxlvnh?si=s2HuzxTqS5umxuriL78O8A '
#  1]
# ['https://open.spotify.com/playlist/1XFWYuHAlMSwHSTAGz9lxo?si=JyyxaSZNTRatGwUG4jdOEg '
#  'https://open.spotify.com/playlist/7LRVLK50iE1zdK3BYmUMWB?si=fhg6ZOuWR9K9zfWtDONGBA '
#  1]
# ['https://open.spotify.com/playlist/1AWxzMvi5MGPH216MkUCGw?si=Dx89ziIKS1SmIOvrRrfE0A '
#  'https://open.spotify.com/playlist/0TJT5w11XrqNr2FhtoAotC?si=nTzLMtu_QnqbyPnTALq2Ug '
#  1]
# ['https://open.spotify.com/playlist/2WR0gud6xcFCSdo0LZVSH8?si=uEiPYfIJQCqA_BmeGEkqTg '
#  'https://open.spotify.com/playlist/1FSwjNbyLDY7wMh0zbKJii?si=g4olOKmgTxCWy6II0-QKbg '
#  1]
# ['https://open.spotify.com/playlist/4YkqZQ67nhXnelAZtJUw4B?si=oHmDColmRnuklOAddHQAaw '
#  'https://open.spotify.com/playlist/5k9cWWnyoseIKuybTwXXOp?si=8VdXq9-vQ1-CNNQN3-2hoQ'
#  0]
# ['https://open.spotify.com/playlist/2QG1nBy93cOPx6QQqQMU2d?si=GeiXnLJ5QrWn_HaILBsx6A '
#  'https://open.spotify.com/playlist/4Tt1Wh71mwIvhu5nif0C1p?si=RQhPS1-SR8O6Jl90TfU7fQ'
#  0]
# ['https://open.spotify.com/playlist/5ISSX85sJQxCPR20TToTUT?si=R4X1eVB5Th6dyRx-ECTH_w '
#  'https://open.spotify.com/playlist/1lwDoto6wMESA4Z4An28Co?si=K5f2ib-8Qk6375afV6ZtNg'
#  0]
# ['https://open.spotify.com/playlist/6YN5BZVQESc4fye0ILuCN5?si=5O7g5S5uSZyps9SzRN_lgg '
#  'https://open.spotify.com/playlist/5CGCfZ7KHZIaIRHTXf47CC?si=n_mrE1mvQ5Wzk7PCtNcf-Q'
#  0]
# ['https://open.spotify.com/playlist/1uoVAanb6g1P9nrorJ88GN?si=fIq9zrEXTHKiU4owWAkTXA '
#  'https://open.spotify.com/playlist/1xFk1UVomG1RYcilwEAfmu?si=kuPjtJ4VRyKZwrnDikBQxw'
#  0]
# ['https://open.spotify.com/playlist/7hAX6khzuOwTcy3nAWL6IX?si=pkSK8p88RS6tppCFUBZDKQ '
#  'https://open.spotify.com/playlist/6WLvPX3eApl3NeDR1yJE4a?si=kk4HsmiFTDyTqft1jIfF6w'
#  0]
# ['https://open.spotify.com/playlist/7wmF65RD08t9ciGY6kIZSi?si=9GTCNZU-ROSv8k26Cy3MsA'
#  'https://open.spotify.com/playlist/7p2lPvgbihma0EGgH6HMdD?si=Dxj_PaLCTvme3a6XCeu_QQ'
#  0]
# ['https://open.spotify.com/playlist/5s6BrCvXB1V1U6WkrbvlcX?si=6Y89x3oPRiO3_C62N8-nIA'
#  'https://open.spotify.com/playlist/0bGo6h4dBfi5a86AgSlrEJ?si=cLpu-eqtRJSPJociBTllhw'
#  0]
# ['https://open.spotify.com/playlist/4cc7Oj0WCxNwzf7hcyrS4G?si=XuYVCIBZT3qPEYfEkwb9NA&fbclid=IwAR0HI0WGupdSpRHP1rDxw8wu2_m-o9vMLjgO0chywcKQLih6Fjdy9Q6Ye1E'
#  'https://open.spotify.com/playlist/5FIYbu78vnCSaYeOU7XIQX?si=sfR1AAxvTiKuF5YB0Bt4dw'
#  0]
# ['https://open.spotify.com/playlist/5xMj86mInzlFppXUGxGkV6?si=wuFeitVJTYKx9485fTjuYw'
#  'https://open.spotify.com/playlist/1dnu7thFGjDG4XAdanvacO?si=puDxtKkeQMmRQWIObOci2g'
#  0]
# ['https://open.spotify.com/playlist/6I6wp3eSZEbFOuz6toRudY?si=Eau3TnBRS4aLdGExSdEqxw'
#  'https://open.spotify.com/playlist/4fcUnlhy1tlIxavhUmtmSy?si=PSj6PtycT9yWneS9lwS0TA'
#  0]
# ['https://open.spotify.com/playlist/3b4DYLK6gguQsxAtfmBf0C?si=SNKFLK7VTweJs0Z96rfBHw'
#  'https://open.spotify.com/playlist/20VsjYLUi8yIulO6l0mxLR?si=zvpZMVYhSF-UprrEWFzbyg'
#  0]
# ['https://open.spotify.com/playlist/6TTthnh3stwR7AgyNlREpX?si=Hh1rXWJXTbOX5BUSesuuqQ'
#  'https://open.spotify.com/playlist/3k9gzqFrnIe3fxzeyVhRNx?si=B_PYqxn0TNWr59g-FTqbjg'
#  0]
# ['https://open.spotify.com/playlist/7EW1G6BVae7nHucF5mbJe3?si=WeONoL7TQDmkYyIldwDmFw'
#  'https://open.spotify.com/playlist/3k7SbojaD1xDyEXZjaksn3?si=HQaSbMeqTO-LtJZQxQmaRg'
#  0]
# ['https://open.spotify.com/playlist/69an3xCIXEtP3jcSPWfKMX?si=mIsHZ3JVTe-HFOJ-RBZRDQ'
#  'https://open.spotify.com/playlist/5m2sRlsUfLh17juvuomrZM?si=nlK4AVH8QkCEfZQEzAAMLw'
#  0]
# ['https://open.spotify.com/user/angel94267/playlist/1ekNExjBeAuBJfp9ZU7j21?si=a9nuMIXRSJGC1lR3xu-0wQ'
#  'https://open.spotify.com/playlist/4B4lFX79W1WYgphMpEp2Ty?si=7QhasmgtT-m1VZ8sSRvd0w'
#  0]
# ['https://open.spotify.com/playlist/3BbT5tKrdqFxeeE3DjGRK0?si=3z_JisIEQFeA4FfZ7nIJrQ'
#  'https://open.spotify.com/playlist/5XxlH4PffVqbf2KQQVgnVC?si=YS1eO_4OQjy8abob-zqnOg'
#  0]
# ['https://open.spotify.com/playlist/2uOx3uPcRy05y5c1TAILIp?si=sQnzOQNARWqDancFyKoO7A'
#  'https://open.spotify.com/user/1vcmfo1btai20s1sn1mz5wa4a/playlist/1Te0ZQDWCGZGwQwWOdX9Ry?si=kRV4BAZ2Q2uUhGpvuFbclQ'
#  0]
# ['https://open.spotify.com/playlist/7jUXg4DTIc1aeAO9tM5j0w?si=i4HlB5a1TCe3bEv2aVu3ig'
#  'https://open.spotify.com/playlist/58i1xtQl1sHERuimiHLYjy?si=cyNoKseYRtWC-NumjmWgZA'
#  0]
# ['https://open.spotify.com/playlist/0lqJgvDkZk3GFxq7VouhWh?si=uehgZ2NfQt22mvRxGCE-kA'
#  'https://open.spotify.com/playlist/3zjXUdzBpxBUtSB7dcZB41?si=6IpxSUQsQTG9NF1UHEVWnA'
#  0]
# ['https://open.spotify.com/playlist/2Cvgv79npINQDfRNVacoQg?si=dAtMU7E2QWmZ_aVbksM_aA'
#  'https://open.spotify.com/playlist/5c9EGBDYF72qOgBOYQhDhY?si=M8SGZ4L6RbSOrFQKRuMLKw'
#  0]
# ['https://open.spotify.com/playlist/4OuBNLWJucVfU6dylW1qMy?si=lfDB54FXTz6-_ArVrTM32A'
#  'https://open.spotify.com/playlist/4lzyljiq7qDljWPJWF3Vcd?si=vHhtrO-KQZm3gv3lrm_tcg'
#  0]
# ['https://open.spotify.com/playlist/6NrfFgXsKoiZwzc0Qg5vkJ?si=KzQ9CwD5RhmWy4_0DMbJ0Q'
#  'https://open.spotify.com/playlist/72xETCQ0zjX3Gt9qJZwgnN?si=MTv9JcRhRE-Lzwo8--oyhw'
#  0]
# ['https://open.spotify.com/user/31m27d7jqkqugy5vjxgedkzjj4by/playlist/2Y001jjQXp1OQQQCPV0nvc?si=BX7gpqi7TlqflifkNSDWDQ'
#  'https://open.spotify.com/playlist/037Kw1v0yBgyxnB5c5JVBg?si=YYattVLHQfuZCn0CgZ_NNA'
#  0]
# ['https://open.spotify.com/playlist/5XGFDHPPSrtZsjAP7EzeFy?si=__03G5dCQua1ZyyXUQTF9Q'
#  'https://open.spotify.com/playlist/0JRlDXWexzLVdaeauPGjz2?si=GwTJGuYsSPeyBGcOmpkzUw'
#  0]
# ['https://open.spotify.com/playlist/4KO1QkjECQjTBWeTcFcyhI?si=-3s-Fji5QraOzlRW04zc5A'
#  'https://open.spotify.com/playlist/6OD8kZoWc8ym5suXz4MCFq?si=sC1g73MfSXe0_qg2YBD4Vg'
#  0]
# ['https://open.spotify.com/user/b0qozr0q4xsyejy063msyu4uh/playlist/7waSXd4aGthjRv5KxFD5ZX?si=PDEwmD2JT2-82CzJ5Gh0Ug'
#  'https://open.spotify.com/playlist/3u0FU6ZCFquAEaORCtI88E?si=Rc0FffmzS36V3gKBYnsogA'
#  0]
# ['https://open.spotify.com/playlist/28oQBp1K8jqSW7XuGjPJp7?si=Km2Cp806Q-SQ4G3sKkG1hQ'
#  'https://open.spotify.com/playlist/037Kw1v0yBgyxnB5c5JVBg?si=YYattVLHQfuZCn0CgZ_NNA'
#  0]
# ['https://open.spotify.com/playlist/0xiqPeE8b6fgagHqOEeu5J?si=htYslIv7RwKAy2ZAyPID9A '
#  'https://open.spotify.com/playlist/0JRlDXWexzLVdaeauPGjz2?si=GwTJGuYsSPeyBGcOmpkzUw'
#  0]
# ['https://open.spotify.com/playlist/6B9q8GdVobKJEHnYGOit6O?si=-V5w1euMTpawe3V3LTc9Bg '
#  'https://open.spotify.com/playlist/6OD8kZoWc8ym5suXz4MCFq?si=sC1g73MfSXe0_qg2YBD4Vg'
#  0]
# ['https://open.spotify.com/playlist/6ApwRH9p3mVYTSk10A44G4?si=M5ZfYTqUTzucccSsMUpjYg '
#  'https://open.spotify.com/playlist/3u0FU6ZCFquAEaORCtI88E?si=Rc0FffmzS36V3gKBYnsogA'
#  0]
# ['https://open.spotify.com/playlist/6IW0N3SjiWJTp4cwqTUrQZ?si=DO6rJA4zTdCOF3XMs8XycA'
#  'https://open.spotify.com/playlist/6elTsuf1JPZQZitMeqwQez?si=uo3dPPIYTiq3Q0YSugSquw'
#  0]
# ['https://open.spotify.com/playlist/1rIgHYILyO2YUENqTum1mV?si=HCphm5MKQpaUX_8itbBTbQ '
#  'https://open.spotify.com/playlist/2vNWRMdJWq5Cdh6GWHuink?si=TM52GZf4QLe0Scyb8RZcLw'
#  0]
# ['https://open.spotify.com/playlist/11YpOEgJ3OtpW1TM3haWa8?si=Pp9Yl3o7SjW3YLiydxNMsA '
#  'https://open.spotify.com/playlist/5a2wrjiadZIzNoaznFhBEM?si=lHDFggNXTfm8KjXCStWBeQ'
#  0]
# ['https://open.spotify.com/playlist/45iFd4TWTTtvl4WDuosCjS?si=lWvvPxTXQG2wCAEufOAxvQ '
#  'https://open.spotify.com/playlist/2n02QGYSxisudxqAWMO9J1?si=tyuoEGHATkCHy6WVfzCTFA'
#  0]
# ['https://open.spotify.com/playlist/1n1hbfajXbjs1ATjQ52ibG?si=1_m9u-QZQ5umyUhZc8toTw '
#  'https://open.spotify.com/playlist/6zwHji3HvBnlA0UMOiuq3B?si=h7ph4d0MRCCOgKM_22WFaw'
#  0]
# ['https://open.spotify.com/playlist/2dDY7Hqbw85CAmGsmj1dkE?si=A_Vnrqw0Q5eQKN3HOeAbRw '
#  'https://open.spotify.com/playlist/6b3rzxp5ICQgHfVOjP2kSl?si=L1LPjYvKQs2chZ2ZTaOA4Q'
#  0]
# ['https://open.spotify.com/playlist/5XGFDHPPSrtZsjAP7EzeFy?si=__03G5dCQua1ZyyXUQTF9Q'
#  'https://open.spotify.com/playlist/2uOx3uPcRy05y5c1TAILIp?si=sQnzOQNARWqDancFyKoO7A'
#  0]
# ['https://open.spotify.com/playlist/4KO1QkjECQjTBWeTcFcyhI?si=-3s-Fji5QraOzlRW04zc5A'
#  'https://open.spotify.com/playlist/7jUXg4DTIc1aeAO9tM5j0w?si=i4HlB5a1TCe3bEv2aVu3ig'
#  0]
# ['https://open.spotify.com/playlist/5rgV1VO4U8whOmsgb7kuN2?si=JJ6-yr5IQwOjIJa4IWPYAw'
#  'https://open.spotify.com/playlist/0lqJgvDkZk3GFxq7VouhWh?si=uehgZ2NfQt22mvRxGCE-kA'
#  0]
# ['https://open.spotify.com/playlist/5r152Yp1aSeXi3Uzltv325?si=S1kAcWqZTxiQe_KdB2XhEg'
#  'https://open.spotify.com/playlist/2Cvgv79npINQDfRNVacoQg?si=dAtMU7E2QWmZ_aVbksM_aA'
#  0]
# ['https://open.spotify.com/user/8dyqkk501hr5l18x3e65lhrif/playlist/5oSBMWAXqtHZaEdX6tfIy5?si=LpOeNH2bSHqTc3ZXuCLOMw'
#  'https://open.spotify.com/playlist/4OuBNLWJucVfU6dylW1qMy?si=lfDB54FXTz6-_ArVrTM32A'
#  0]
# ['https://open.spotify.com/playlist/4hMHSNALj4yFMX6rRRzAKV?si=kwxyTCnOSf6tfZJlxK7bbA'
#  'https://open.spotify.com/playlist/4CgVfYzMtriEMyMpP6RV95?si=8aiWdvzyR3iQdKwKDNg-gg'
#  0]
# ['https://open.spotify.com/playlist/1HZJcEispDQmMdJXDgmzGZ?si=AfQ4rnYFTNGcGpeEdqPvWA'
#  'https://open.spotify.com/playlist/3u0FU6ZCFquAEaORCtI88E?si=Rc0FffmzS36V3gKBYnsogA'
#  0]
# ['https://open.spotify.com/playlist/5uj7VBiyRrtRFy3LTxgmlz?si=VgmhDASBTdie2Y4REnlTOA'
#  'https://open.spotify.com/playlist/1xRULc1Pl6idSuMvLV5icV?si=GWemC-uLT7m1ou7LcVqH2Q'
#  0]
# ['https://open.spotify.com/playlist/3S3CQuepi4z9CjupXZf1MX?si=JQ9oWe1SS1OJqFZa8XlsJQ'
#  'https://open.spotify.com/playlist/3HbFyu4KGH8IDrJtRTP7S9?si=gSs6_tiSSESAHtvAYR30zA'
#  0]
# ['https://open.spotify.com/user/21mw7w6rcbfrryca2hhlhazzi/playlist/0PiN0vClqosnTqqF0TAtCX?si=J7p0rZcwRJ23L-NTHfVCmA'
#  'https://open.spotify.com/playlist/72xETCQ0zjX3Gt9qJZwgnN?si=MTv9JcRhRE-Lzwo8--oyhw'
#  0]

# %%
count = 0
calculation = [ ]
ans_big = [ ]          #最後處理過的每組變數，也是最終要的變數串列
ans_set = [ ]          #一組成對樣本計算過後的變數值

for i in range(len(values)):
    
    for j in range(2):
        
        input_url = values[i][j]
        calculation.append(get_spotify_data(input_url))
        
        count += 1                                         
        if count == 2:
            
            for d1 ,d2 in zip(calculation[0],calculation[1]):      #這個迴圈為的是將成對樣本兩兩相減的絕對值存成串列
                
                x = abs(float(d1)-float(d2))      
                ans_set.append(x)               
                
            ans_big.append(ans_set)             
            ans_set = [ ]                        
            count = 0                           
            calculation = [ ]                    

        else:                       #這表示如果是第1個網址，就先不要計算(收割)，先繼續等待第2網址到來才能開搞
            pass
    print(i, 'done')
        
print(ans_big)
# Out:
# 0 done
# 1 done
# 2 done
# 3 done
# 4 done
# 5 done
# 6 done
# 7 done
# 8 done
# 9 done
# 10 done
# 11 done
# 12 done
# 13 done
# 14 done
# 15 done
# 16 done
# 17 done
# 18 done
# 19 done
# 20 done
# 21 done
# 22 done
# 23 done
# 24 done
# 25 done
# 26 done
# 27 done
# 28 done
# 29 done
# 30 done
# 31 done
# 32 done
# 33 done
# 34 done
# 35 done
# 36 done
# 37 done
# 38 done
# 39 done
# 40 done
# 41 done
# 42 done
# 43 done
# 44 done
# 45 done
# 46 done
# 47 done
# 48 done
# 49 done
# 50 done
# 51 done
# 52 done
# 53 done
# 54 done
# 55 done
# 56 done
# 57 done
# 58 done
# 59 done
# 60 done
# 0      0.009151  0.057288             1
# 1      0.006542  0.112202             1
# 2      0.043105  0.056783             1
# 3      0.028839  0.007555             1
# 4      0.019343  0.010862             1
# ..          ...       ...           ...
# 94     0.011458  0.042074             0
# 95     0.006091  0.095504             0
# 96     0.016703  0.142177             0
# 97     0.020147  0.112745             0
# 98     0.054979  0.008313             0
#
# [99 rows x 3 columns]

# %%
from sklearn import preprocessing, linear_model
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection  import train_test_split
plt.style.use('ggplot')
plt.rcParams['font.family']='SimHei' #⿊體

# %%
#切分訓練 測試資料
x = df_test_final[['speechiness','valence']]
y = df_test_final[['relationship']]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 20191221)   #random_state 種子值

x_train
# Out:
#     speechiness   valence
# 80     0.100944  0.060048
# 43     0.013765  0.162051
# 62     0.022374  0.037410
# 73     0.015692  0.013474
# 28     0.094101  0.159617
# ..          ...       ...
# 90     0.036086  0.034029
# 89     0.012502  0.122377
# 25     0.007868  0.048907
# 15     0.050514  0.162904
# 14     0.102449  0.046046
#
# [79 rows x 2 columns]

# %%
from sklearn.preprocessing  import StandardScaler
sc = StandardScaler()
sc.fit(x_train)

x_train_nor=sc.transform(x_train)
x_test_nor=sc.transform(x_test)

# %%
#訓練資料分類效果(3個參數)
from sklearn.linear_model  import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train_nor,y_train)

# 印出係數
print(lr.coef_)
# 印出截距
print(lr.intercept_ )
# Out:
# [[0.05915177 0.08194771]]
# [0.16945703]
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#檢查樣本外
np.round(lr.predict_proba(x_test_nor),5)
# Out:
# array([[0.48699, 0.51301],
#        [0.44135, 0.55865],
#        [0.45274, 0.54726],
#        [0.46174, 0.53826],
#        [0.49437, 0.50563],
#        [0.45829, 0.54171],
#        [0.4386 , 0.5614 ],
#        [0.42884, 0.57116],
#        [0.4393 , 0.5607 ],
#        [0.46807, 0.53193],
#        [0.46693, 0.53307],
#        [0.4347 , 0.5653 ],
#        [0.44337, 0.55663],
#        [0.42591, 0.57409],
#        [0.4232 , 0.5768 ],
#        [0.44472, 0.55528],
#        [0.49693, 0.50307],
#        [0.46569, 0.53431],
#        [0.43808, 0.56192],
#        [0.45508, 0.54492]])

# %%
df_test_final = pd.DataFrame(cross, columns = ["speechiness", "valence", "relationship"])

# Removed observations without valence

df_test_final = df_test_final[~df_test_final["speechiness"].isna()]
train, validation = train_test_split(df_test_final, test_size=0.1, random_state = 123)
X_train = train.loc[:, ["speechiness", "valence"]].values
y_train = train.loc[:, "relationship"].values

# Fit Logistic regression classifier

clf = LogisticRegression()
clf.fit(X_train, y_train)
X_validation = validation.loc[:, ["speechiness", "valence"]].values
y_validation = validation.loc[:, "relationship"].values

y_hat = clf.predict(X_validation)
# Calculating confusion matrix

nunique_labels = len(set(y_train))
conf_mat_shape = (nunique_labels, nunique_labels)
conf_mat = np.zeros(conf_mat_shape, dtype=int)

for actual, predict in zip(y_hat, y_validation):
    conf_mat[actual, predict] += 1

# Calculating accuracy

accuracy = (conf_mat[0, 0] + conf_mat[1, 1])/conf_mat.sum()

print(conf_mat)
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# [[0 0]
#  [4 6]]
# Accuracy: 60.00%
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
